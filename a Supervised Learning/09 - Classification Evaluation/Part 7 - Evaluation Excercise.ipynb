# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease
# Out:
# C:\Users\Damianus Deni\Miniconda3\envs\jcopml\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
from luwiji.logistic_regression import illustration

# %%
illustration.mushroom

# %% [markdown]
# # Import Data

# %%
pd.options.display.max_columns = 100

# %%
df = pd.read_csv("data/mushrooms.csv")
df.head(50)
# Out:
#     edible cap_shape cap_surface cap_color  bruises     odor gill_attachment  \
# 0    False    convex      smooth     brown     True  pungent            free
# 1     True    convex      smooth    yellow     True   almond            free
# 2     True      bell      smooth     white     True    anise            free
# 3    False    convex       scaly     white     True  pungent            free
# 4     True    convex      smooth      gray    False     none            free
# 5     True    convex       scaly    yellow     True   almond            free
# 6     True      bell      smooth     white     True   almond            free
# 7     True      bell       scaly     white     True    anise            free
# 8    False    convex       scaly     white     True  pungent            free
# 9     True      bell      smooth    yellow     True   almond            free
# 10    True    convex       scaly    yellow     True    anise            free
# 11    True    convex       scaly    yellow     True   almond            free
# 12    True      bell      smooth    yellow     True   almond            free
# 13   False    convex       scaly     white     True  pungent            free
# 14    True    convex     fibrous     brown    False     none            free
# 15    True    sunken     fibrous      gray    False     none            free
# 16    True      flat     fibrous     white    False     none            free
# 17   False    convex      smooth     brown     True  pungent            free
# 18   False    convex       scaly     white     True  pungent            free
# 19   False    convex      smooth     brown     True  pungent            free
# 20    True      bell      smooth    yellow     True   almond            free
# 21   False    convex       scaly     brown     True  pungent            free
# 22    True      bell       scaly    yellow     True    anise            free
# 23    True      bell       scaly     white     True   almond            free
# 24    True      bell      smooth     white     True    anise            free
# 25   False      flat      smooth     white     True  pungent            free
# 26    True    convex       scaly    yellow     True   almond            free
# 27    True    convex       scaly     white     True    anise            free
# 28    True      flat     fibrous     brown    False     none            free
# 29    True    convex      smooth    yellow     True   almond            free
# 30    True      bell      smooth    yellow     True    anise            free
# 31   False    convex       scaly     white     True  pungent            free
# 32    True    convex       scaly    yellow     True    anise            free
# 33    True    convex       scaly     brown     True    anise            free
# 34    True      bell       scaly    yellow     True    anise            free
# 35    True    convex     fibrous    yellow     True    anise            free
# 36    True    sunken     fibrous      gray    False     none            free
# 37   False    convex       scaly     brown     True  pungent            free
# 38    True    convex     fibrous    yellow     True   almond            free
# 39    True      bell      smooth    yellow     True    anise            free
# 40    True      bell       scaly    yellow     True   almond            free
# 41    True    convex       scaly    yellow     True    anise            free
# 42    True    convex     fibrous     brown    False     none            free
# 43   False    convex       scaly     white     True  pungent            free
# 44    True    convex      smooth    yellow     True   almond            free
# 45    True    convex       scaly     white     True   almond            free
# 46    True    convex       scaly    yellow     True    anise            free
# 47    True    convex      smooth     white     True    anise            free
# 48    True    convex       scaly    yellow     True    anise            free
# 49    True      flat       scaly    yellow     True    anise            free
#
#    gill_spacing gill_size gill_color stalk_shape stalk_root  \
# 0         close    narrow      black   enlarging      equal
# 1         close     broad      black   enlarging       club
# 2         close     broad      brown   enlarging       club
# 3         close    narrow      brown   enlarging      equal
# 4       crowded     broad      black    tapering      equal
# 5         close     broad      brown   enlarging       club
# 6         close     broad       gray   enlarging       club
# 7         close     broad      brown   enlarging       club
# 8         close    narrow       pink   enlarging      equal
# 9         close     broad       gray   enlarging       club
# 10        close     broad       gray   enlarging       club
# 11        close     broad      brown   enlarging       club
# 12        close     broad      white   enlarging       club
# 13        close    narrow      black   enlarging      equal
# 14      crowded     broad      brown    tapering      equal
# 15        close    narrow      black   enlarging      equal
# 16      crowded     broad      black    tapering      equal
# 17        close    narrow      brown   enlarging      equal
# 18        close    narrow      brown   enlarging      equal
# 19        close    narrow      black   enlarging      equal
# 20        close     broad      black   enlarging       club
# 21        close    narrow      brown   enlarging      equal
# 22        close     broad      black   enlarging       club
# 23        close     broad      white   enlarging       club
# 24        close     broad       gray   enlarging       club
# 25        close    narrow      brown   enlarging      equal
# 26        close     broad      brown   enlarging       club
# 27        close     broad      white   enlarging       club
# 28        close    narrow      black   enlarging      equal
# 29      crowded    narrow      brown    tapering    bulbous
# 30        close     broad       gray   enlarging       club
# 31        close    narrow      black   enlarging      equal
# 32        close     broad      brown   enlarging       club
# 33        close     broad       pink   enlarging     rooted
# 34        close     broad      brown   enlarging       club
# 35      crowded    narrow      white    tapering    bulbous
# 36        close    narrow      black   enlarging      equal
# 37        close    narrow      white   enlarging      equal
# 38      crowded    narrow       pink    tapering    bulbous
# 39        close     broad      black   enlarging       club
# 40        close     broad      brown   enlarging       club
# 41        close     broad      brown   enlarging     rooted
# 42        close    narrow       gray   enlarging      equal
# 43        close    narrow       pink   enlarging      equal
# 44        close     broad      white   enlarging       club
# 45        close     broad      brown   enlarging       club
# 46        close     broad      black   enlarging       club
# 47        close     broad      white   enlarging       club
# 48        close     broad      brown   enlarging     rooted
# 49        close     broad      white   enlarging     rooted
#
#    stalk_surface_above_ring stalk_surface_below_ring stalk_color_above_ring  \
# 0                    smooth                   smooth                  white
# 1                    smooth                   smooth                  white
# 2                    smooth                   smooth                  white
# 3                    smooth                   smooth                  white
# 4                    smooth                   smooth                  white
# 5                    smooth                   smooth                  white
# 6                    smooth                   smooth                  white
# 7                    smooth                   smooth                  white
# 8                    smooth                   smooth                  white
# 9                    smooth                   smooth                  white
# 10                   smooth                   smooth                  white
# 11                   smooth                   smooth                  white
# 12                   smooth                   smooth                  white
# 13                   smooth                   smooth                  white
# 14                   smooth                  fibrous                  white
# 15                   smooth                   smooth                  white
# 16                   smooth                   smooth                  white
# 17                   smooth                   smooth                  white
# 18                   smooth                   smooth                  white
# 19                   smooth                   smooth                  white
# 20                   smooth                   smooth                  white
# 21                   smooth                   smooth                  white
# 22                   smooth                   smooth                  white
# 23                   smooth                   smooth                  white
# 24                   smooth                   smooth                  white
# 25                   smooth                   smooth                  white
# 26                   smooth                   smooth                  white
# 27                   smooth                   smooth                  white
# 28                   smooth                   smooth                  white
# 29                   smooth                   smooth                  white
# 30                   smooth                   smooth                  white
# 31                   smooth                   smooth                  white
# 32                   smooth                   smooth                  white
# 33                   smooth                    scaly                  white
# 34                   smooth                   smooth                  white
# 35                   smooth                   smooth                  white
# 36                   smooth                   smooth                  white
# 37                   smooth                   smooth                  white
# 38                   smooth                   smooth                  white
# 39                   smooth                   smooth                  white
# 40                   smooth                   smooth                  white
# 41                   smooth                    scaly                  white
# 42                   smooth                   smooth                  white
# 43                   smooth                   smooth                  white
# 44                   smooth                   smooth                  white
# 45                   smooth                   smooth                  white
# 46                   smooth                   smooth                  white
# 47                   smooth                   smooth                  white
# 48                   smooth                    scaly                  white
# 49                   smooth                    scaly                  white
#
#    stalk_color_below_ring veil_type veil_color  ring_number   ring_type  \
# 0                   white   partial      white            1     pendant
# 1                   white   partial      white            1     pendant
# 2                   white   partial      white            1     pendant
# 3                   white   partial      white            1     pendant
# 4                   white   partial      white            1  evanescent
# 5                   white   partial      white            1     pendant
# 6                   white   partial      white            1     pendant
# 7                   white   partial      white            1     pendant
# 8                   white   partial      white            1     pendant
# 9                   white   partial      white            1     pendant
# 10                  white   partial      white            1     pendant
# 11                  white   partial      white            1     pendant
# 12                  white   partial      white            1     pendant
# 13                  white   partial      white            1     pendant
# 14                  white   partial      white            1  evanescent
# 15                  white   partial      white            1     pendant
# 16                  white   partial      white            1  evanescent
# 17                  white   partial      white            1     pendant
# 18                  white   partial      white            1     pendant
# 19                  white   partial      white            1     pendant
# 20                  white   partial      white            1     pendant
# 21                  white   partial      white            1     pendant
# 22                  white   partial      white            1     pendant
# 23                  white   partial      white            1     pendant
# 24                  white   partial      white            1     pendant
# 25                  white   partial      white            1     pendant
# 26                  white   partial      white            1     pendant
# 27                  white   partial      white            1     pendant
# 28                  white   partial      white            1     pendant
# 29                  white   partial      white            1     pendant
# 30                  white   partial      white            1     pendant
# 31                  white   partial      white            1     pendant
# 32                  white   partial      white            1     pendant
# 33                  white   partial      white            1     pendant
# 34                  white   partial      white            1     pendant
# 35                  white   partial      white            1     pendant
# 36                  white   partial      white            1     pendant
# 37                  white   partial      white            1     pendant
# 38                  white   partial      white            1     pendant
# 39                  white   partial      white            1     pendant
# 40                  white   partial      white            1     pendant
# 41                  white   partial      white            1     pendant
# 42                  white   partial      white            1     pendant
# 43                  white   partial      white            1     pendant
# 44                  white   partial      white            1     pendant
# 45                  white   partial      white            1     pendant
# 46                  white   partial      white            1     pendant
# 47                  white   partial      white            1     pendant
# 48                  white   partial      white            1     pendant
# 49                  white   partial      white            1     pendant
#
#    spore_print_color population  habitat
# 0              black  scattered    urban
# 1              brown   numerous  grasses
# 2              brown   numerous  meadows
# 3              black  scattered    urban
# 4              brown   abundant  grasses
# 5              black   numerous  grasses
# 6              black   numerous  meadows
# 7              brown  scattered  meadows
# 8              black    several  grasses
# 9              black  scattered  meadows
# 10             brown   numerous  grasses
# 11             black  scattered  meadows
# 12             brown  scattered  grasses
# 13             brown    several    urban
# 14             black   abundant  grasses
# 15             brown   solitary    urban
# 16             brown   abundant  grasses
# 17             black  scattered  grasses
# 18             brown  scattered    urban
# 19             brown  scattered    urban
# 20             brown  scattered  meadows
# 21             brown    several  grasses
# 22             brown  scattered  meadows
# 23             brown   numerous  meadows
# 24             black  scattered  meadows
# 25             brown    several  grasses
# 26             brown   numerous  meadows
# 27             brown   numerous  meadows
# 28             black   solitary    urban
# 29             brown    several    woods
# 30             brown   numerous  meadows
# 31             brown  scattered    urban
# 32             brown   numerous  meadows
# 33             brown   solitary    paths
# 34             brown  scattered  meadows
# 35             brown    several    woods
# 36             black    several    urban
# 37             brown  scattered    urban
# 38             brown    several    woods
# 39             black  scattered  meadows
# 40             brown  scattered  grasses
# 41             black   solitary    paths
# 42             black   solitary    urban
# 43             brown    several  grasses
# 44             black   numerous  meadows
# 45             brown   numerous  grasses
# 46             black  scattered  meadows
# 47             brown   numerous  meadows
# 48             brown  scattered    paths
# 49             black  scattered    paths

# %% [markdown]
# #### plot missing values

# %%
plot_missing_value(df)

# %%
df.drop(columns="stalk_root", inplace=True)

# %%
df.edible.value_counts(normalize=True)
# Out:
# True     0.517971
# False    0.482029
# Name: edible, dtype: float64

# %% [markdown]
# # Tips Klasifikasi: Association Matrix
# klasifikasi tidak ada korelasi, tapi adanya Matriks Asosiasi

# %%
from jcopml.plot import plot_association_matrix

# %%
plot_association_matrix(df, "edible")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-5d34a3be2434> in <module>
# ----> 1 plot_association_matrix(df, "edible")
#
# ~\Miniconda3\envs\jcopml\lib\site-packages\jcopml\plot\_association_matrix.py in plot_association_matrix(df, target_col, categoric_col)
#      94     single_category_col = list(tmp[tmp == 1].index)
#      95     if single_category_col:
# ---> 96         raise ValueError(f"Categorical column should have at least 2 category\n"
#      97                          f"You should remove these column from your data -> {', '.join(single_category_col)}")
#      98
#
# ValueError: Categorical column should have at least 2 category
# You should remove these column from your data -> veil_type

# %%
# veil type hanya punya 1 kategori jadi dianggap bukan data, maka harus didrop
df.drop(columns="veil_type", inplace=True)

# %%
plot_association_matrix(df, "edible")
# Out:
# interactive(children=(ToggleButtons(description='method', options=("Cramer's V", 'Proficiency U(X|Y)', 'Profic…

# %% [markdown]
# # Dataset Splitting

# %%
X = df.drop(columns="edible")
y = df.edible

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6499, 20), (1625, 20), (6499,), (1625,))

# %% [markdown]
# # Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from jcopml.tuning import random_search_params as rsp
# Out:
# C:\Users\Damianus Deni\Miniconda3\envs\jcopml\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\Damianus Deni\Miniconda3\envs\jcopml\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
preprocessor = ColumnTransformer([
    ('categoric', cat_pipe(encoder='onehot'), ["odor", "gill_color", "ring_type", "spore_print_color"]),
])


pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', LogisticRegression(solver='lbfgs', n_jobs=-1, random_state=42))
])


model = RandomizedSearchCV(pipeline, rsp.logreg_params, cv=5, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   27.7s
# {'algo__C': 17.71884735480683, 'algo__fit_intercept': False}
# 0.9938452069549162 0.9938450879374667 0.9975384615384615
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   31.0s finished

# %% [markdown]
# # Check Importance

# %%
df_imp = mean_score_decrease(X_train, y_train, model, plot=True, topk=10)

# %%
# Only with Odor
preprocessor = ColumnTransformer([
    ('categoric', cat_pipe(encoder='onehot'), ["odor", "spore_print_color"]),
])


pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', LogisticRegression(solver='lbfgs', n_jobs=-1, random_state=42))
])


model = RandomizedSearchCV(pipeline, rsp.logreg_params, cv=5, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.1s
# {'algo__C': 0.17670169402947963, 'algo__fit_intercept': True}
# 0.9932297276504077 0.9932294664534849 0.9975384615384615
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   11.9s finished

# %% [markdown]
# # Evaluation

# %%
from jcopml.plot import plot_classification_report, plot_confusion_matrix, plot_roc_curve, plot_pr_curve

# %%
plot_classification_report(X_train, y_train, X_test, y_test, model, report=True)
# Out:
# Train report
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99      3133
#         True       0.99      1.00      0.99      3366
#
#     accuracy                           0.99      6499
#    macro avg       0.99      0.99      0.99      6499
# weighted avg       0.99      0.99      0.99      6499
#
#
# Test report
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       783
#         True       1.00      1.00      1.00       842
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
plot_confusion_matrix(X_train, y_train, X_test, y_test, model)

# %%
plot_roc_curve(X_train, y_train, X_test, y_test, model)

# %%
plot_pr_curve(X_train, y_train, X_test, y_test, model)

# %% [markdown]
# # Visualisasi

# %%
import seaborn as sns

# %%
sns.countplot("spore_print_color",data=df, hue="edible")
